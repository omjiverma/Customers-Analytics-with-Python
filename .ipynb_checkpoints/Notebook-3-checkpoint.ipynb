# %% [markdown]
# # Purchase Predictive Analysis

# %% [markdown]
# ## Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="whitegrid", rc=custom_params,palette='Set1')
from sklearn.linear_model import LogisticRegression 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Data

# %%
df_purchase = pd.read_csv('purchase_segmented.csv',index_col=0)

# %%
df_purchase.head()
# Out:
#            Day  Incidence  Brand  Quantity  Last_Inc_Brand  Last_Inc_Quantity  \
# ID
# 200000001    1          0      0         0               0                  0
# 200000001   11          0      0         0               0                  0
# 200000001   12          0      0         0               0                  0
# 200000001   16          0      0         0               0                  0
# 200000001   18          0      0         0               0                  0
#
#            Price_1  Price_2  Price_3  Price_4  ...  Promotion_5  Sex  \
# ID                                             ...
# 200000001     1.59     1.87     2.01     2.09  ...            0    0
# 200000001     1.51     1.89     1.99     2.09  ...            0    0
# 200000001     1.51     1.89     1.99     2.09  ...            0    0
# 200000001     1.52     1.89     1.98     2.09  ...            0    0
# 200000001     1.52     1.89     1.99     2.09  ...            0    0
#
# ...

# %% [markdown]
# ## Data Preparation

# %%
df_purchase_predictors = df_purchase.copy()

# %%
segment_dummies = pd.get_dummies(df_purchase_predictors['Segment'], prefix = 'Segment', prefix_sep = '_')
df_purchase_predictors = pd.concat([df_purchase_predictors, segment_dummies], axis = 1)

# %% [markdown]
# ## Purchase Probability Model

# %%
y = df_purchase_predictors['Incidence']

# %%
X = df_purchase_predictors[['Price_1','Price_2','Price_3','Price_4','Price_5']].mean(axis=1)
X = pd.DataFrame(X,columns=['Price_mean'])

# %%
lr_purchase = LogisticRegression(solver = 'sag')
lr_purchase.fit(X, y)
# Out:
# LogisticRegression(solver='sag')

# %%
beta = lr_purchase.coef_[0,0]

# %% [markdown]
# ## Price Elasticity of Purchase Probability

# %%
# Generating price sequence from 0.5 to 3.0
price_range = np.arange(0.5, 3.0, 0.01)
df_price_range = pd.DataFrame(price_range,columns=['Price_range'])

# %%
# Purchase Porbability prediction
purchase_proba = lr_purchase.predict_proba(price_range.reshape(-1,1))[:,1]

# %%
#price elasticity
pe = beta * (df_price_range['Price_range'] * (1- purchase_proba))
df_pe = df_price_range
df_pe['Mean_PE'] = pe

# %%
sns.lineplot(data=df_pe,x='Price_range',y='Mean_PE')
plt.title('Price Elasiticity of Purchase Probability',fontsize=16)
plt.ylabel('Elasticity');

# %% [markdown]
# * More Customers prefers to buy at lower price

# %% [markdown]
# ## Purchase Probability by Segment

# %% [markdown]
# ### Segment 1

# %%
segment_1 = df_purchase_predictors[df_purchase_predictors['Segment'] == 1]

# %%
y1 = segment_1['Incidence']
X1 = segment_1[['Price_1','Price_2','Price_3','Price_4','Price_5']].mean(axis=1)
X1 = pd.DataFrame(X1,columns=['Price_mean'])

# %%
lr_segment_1 = LogisticRegression(solver = 'sag')
lr_segment_1.fit(X1, y1)
# Out:
# LogisticRegression(solver='sag')

# %%
beta1 =lr_segment_1.coef_[0,0]

# %%
purchase_segment1_proba = lr_segment_1.predict_proba(price_range.reshape(-1,1))[:,1]
pe_1 = beta1 * (price_range * (1- purchase_segment1_proba))
df_pe_1 = pd.DataFrame(price_range,columns=['Price_range'])
df_pe_1['Mean_PE'] = pe_1

# %%
df_segment_pe = df_pe_1
df_segment_pe = df_segment_pe.set_index('Price_range')
df_segment_pe.rename(columns={'Mean_PE':'Segment_1'},inplace=True)

# %%
df_segment_pe.plot(figsize=(10,6))
plt.title('Price Elasticity of Purchase Probabilities');

# %% [markdown]
# ## Segment 2

# %%
segment_2 = df_purchase_predictors[df_purchase_predictors['Segment'] == 2]
y2 = segment_2['Incidence']
X2 = segment_2[['Price_1','Price_2','Price_3','Price_4','Price_5']].mean(axis=1)
X2 = pd.DataFrame(X2,columns=['Price_mean'])

# %%
lr_segment_2 = LogisticRegression(solver = 'sag')
lr_segment_2.fit(X2, y2)
# Out:
# LogisticRegression(solver='sag')

# %%
beta2 =lr_segment_2.coef_[0,0]

purchase_segment2_proba = lr_segment_2.predict_proba(price_range.reshape(-1,1))[:,1]
pe_2 = beta2 * (price_range * (1- purchase_segment2_proba))
df_segment_pe['Segment_2'] = pe_2

# %%
df_segment_pe['Segment_2'].plot(figsize=(10,6))
plt.title('Price Elasticity of Purchase Probabilities');

# %% [markdown]
# ### Segment 0

# %%
segment_0 = df_purchase_predictors[df_purchase_predictors['Segment'] == 0]
y0 = segment_0['Incidence']
X0 = segment_0[['Price_1','Price_2','Price_3','Price_4','Price_5']].mean(axis=1)
X0 = pd.DataFrame(X0,columns=['Price_mean'])

# %%
lr_segment_0 = LogisticRegression(solver = 'sag')
lr_segment_0.fit(X0, y0)
# Out:
# LogisticRegression(solver='sag')

# %%
beta0 =lr_segment_0.coef_[0,0]

purchase_segment0_proba = lr_segment_0.predict_proba(price_range.reshape(-1,1))[:,1]
pe_0 = beta0 * (price_range * (1- purchase_segment0_proba))
df_segment_pe['Segment_0'] = pe_0

# %%
df_segment_pe['Segment_0'].plot(figsize=(10,6))
plt.title('Price Elasticity of Purchase Probabilities');

# %% [markdown]
# ### Segment 3

# %%
segment_3 = df_purchase_predictors[df_purchase_predictors['Segment'] == 3]
y3 = segment_3['Incidence']
X3 = segment_3[['Price_1','Price_2','Price_3','Price_4','Price_5']].mean(axis=1)
X3 = pd.DataFrame(X3,columns=['Price_mean'])

# %%
lr_segment_3 = LogisticRegression(solver = 'sag')
lr_segment_3.fit(X3, y3)
# Out:
# LogisticRegression(solver='sag')

# %%
beta3 =lr_segment_3.coef_[0,0]

purchase_segment3_proba = lr_segment_3.predict_proba(price_range.reshape(-1,1))[:,1]
pe_3 = beta3 * (price_range * (1- purchase_segment3_proba))
df_segment_pe['Segment_3'] = pe_3

# %%
df_segment_pe['Segment_3'].plot(figsize=(10,6))
plt.title('Price Elasticity of Purchase Probabilities');

# %% [markdown]
# ### Comparing All Price Elasticity of Purchase Probabilities

# %%
df_segment_pe['Mean_PE'] = df_pe['Mean_PE'].values

# %%
df_segment_pe.plot(figsize=(10,6))
plt.xlabel('Price')
plt.ylabel('Elasticity')
plt.title('Price Elasticity of Purchase Probability');
